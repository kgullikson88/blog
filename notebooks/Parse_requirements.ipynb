# %% [markdown]
# # Parse the requirements file
# The previous notebook, 'PyPi_Metadata.ipynb', parsed the requirements out of every package on the pypi server. The output was a file that looks like this:
#
# ```
# packages/astrodbkit-0.2.0
#
# packages/astrodendro-0.1.0
# aplpy
# astropy
# matplotlib
# numpy
#
# packages/astroid-1.4.4
#
# packages/astroimtools-0.1
# git+http://github.com/astropy/astropy.git#egg=astropy
# astropy-helpers
# cython>=0.23.4
# distribute==0.0
# matplotlib
# numpy
# ```
#
# The packages start with the name of the python package, followed by the dependencies I was able to parse. Many of them have no dependencies; for now I will assume that is correct even though I know it is not true. Any package that programmatically defines the requirements in the setup.py, and which have no requirements files, are not found.
#
# The purpose of this notebook will largely just be to parse the output file into a pandas dataframe.

# %%
import pandas as pd
from collections import defaultdict
import os
import numpy as np
import requirements
import xmlrpclib

# I need this to separate the package name from its version
client = xmlrpclib.ServerProxy('http://pypi.python.org/pypi')
packages = client.list_packages()

# %% [markdown]
# ## 1: Parse the requirements for each package

# %%
datadict = defaultdict(list)
with open('requirements.txt', 'r') as infile:
    new_package = True
    for line in infile:
        if line.strip() == '':
            new_package = True
            #print(package_name)
            if package_name not in datadict['package']:
                datadict['package'].append(package_name)
                datadict['requirement'].append(np.nan)
            continue
        
        if new_package:
            # If this is the case, the current line gives the name of the package
            package_name = os.path.basename(line).strip()
            new_package = False
        else:
            # This line gives a requirement for the current package
            try:
                for req in requirements.parse(line.strip()):
                    datadict['package'].append(package_name)
                    datadict['requirement'].append(req.name)
            except ValueError:
                pass
                
            #datadict['package'].append(package_name)
            #datadict['requirement'].append(line.strip())

# Convert to dataframe
df = pd.DataFrame(data=datadict)
df.head()
# Out:
#              package     requirement
# 0  02exercicio-1.0.0             NaN
# 1    0x10c-asm-0.0.2             NaN
# 2   115wangpan-0.7.6  beautifulsoup4
# 3   115wangpan-0.7.6          homura
# 4   115wangpan-0.7.6        humanize

# %% [markdown]
# # 2: Get the base package name from the package string
# The package column of the dataframe currently contains the name of the package as well as the version string. I need to separate the two. For that, I will use the package list from pypi itself again.

# %%
df['package_name'] = np.nan
df['package_version'] = np.nan
for i, package in enumerate(packages):
    if i % 100 == 0:
        print('Package {}: {}'.format(i+1, package))
    for release in client.package_releases(package):
        pkg_str = '{}-{}'.format(package, release)
        idx = df.loc[df.package == pkg_str].index
        if len(idx) > 0:
            df.loc[idx, 'package_name'] = package
            df.loc[idx, 'package_version'] = release
df.head()
# Out:
# Package 1: 0-._.-._.-._.-._.-._.-._.-0
# Package 101: ABBYY
# Package 201: acidfile
# Package 301: addhrefs
# Package 401: adspygoogle
# Package 501: agd_tools
# Package 601: aima
# Package 701: aiorequests
# Package 801: ajenti.plugin.datetime
# Package 901: aldryn-cms
# Package 1001: aliyun-oss
# Package 1101: altered.states
# Package 1201: ampl
# Package 1301: android_sms_exporter
# Package 1401: ansiblereporter
# Package 1501: anybox.testing.datetime
# Package 1601: apidev-djaloha
# Package 1701: Appium-Python-Client
# Package 1801: apycot
# Package 1901: archiwe
# Package 2001: argumentsprocessor
# Package 2101: arrowhead
# Package 2201: Ashser_AthleteList
# Package 2301: assert_tools
# Package 2401: asv_seo
# Package 2501: AthleteClass
# Package 2601: AttendanceTracker
# Package 2701: authgoogle-middleware
# Package 2801: automate
# Package 2901: avatarsio
# Package 3001: awsjump
# Package 3101: azure-servicemanagement-legacy
# Package 3201: backquotes
# Package 3301: bambu-analytics
# Package 3401: bard
# Package 3501: basil_daq
# Package 3601: bcbio-gff
# Package 3701: beanstalkclient
# Package 3801: bein-htminilims
# Package 3901: betamax-matchers
# Package 4001: BibReview
# Package 4101: BingTranslator
# Package 4201: birdhousebuilder.recipe.solr
# Package 4301: bitquant
# Package 4401: BlazeUtils
# Package 4501: b-logcat
# Package 4601: bob.bio.base
# Package 4701: boiler
# Package 4801: bootloaderProfiler
# Package 4901: bottle-gui
# Package 5001: boxup_bicolormatrix
# Package 5101: bread
# Package 5201: Brownie
# Package 5301: btsbots
# Package 5401: Building-C-projects-ots.make
# Package 5501: buoy
# Package 5601: bw-stats-toolkit
# Package 5701: c2.search.kananormalizer
# Package 5801: cain
# Package 5901: campaign-monitor-api
# Package 6001: capturer
# Package 6101: casper
# Package 6201: cbcpost
# Package 6301: cec2013single
# Package 6401: Centric8Python
# Package 6501: cgc-cli
# Package 6601: chanjo-report
# Package 6701: checker
# Package 6801: chemview
# Package 6901: chk
# Package 7001: ciao
# Package 7101: ciso8601
# Package 7201: clancy
# Package 7301: cleo
# Package 7401: clip.py
# Package 7501: cloudeebus
# Package 7601: cloudydict
# Package 7701: Cmdopt
# Package 7801: cmsplugin-link-extended
# Package 7901: cnx-archive
# Package 8001: codehack
# Package 8101: coinkite-api
# Package 8201: collective.backtowork
# Package 8301: collective.collage.innerfade
# Package 8401: collective.discussionintegration.plonegazette
# Package 8501: collective.genericsetup.ldap
# Package 8601: collective.js.charcount
# Package 8701: collective.linguasitemap
# Package 8801: collective.pageheader
# Package 8901: collective.portlet.ngcollection
# Package 9001: collective.realestatebroker
# Package 9101: collective.searchform
# Package 9201: collective.trajectory
# Package 9301: collective.zrtresource
# Package 9401: comicnamer
# Package 9501: comp-exp
# Package 9601: conductance
# Package 9701: confluencer
# Package 9801: consul2sns
# Package 9901: ConvUtils
# Package 10001: coreclient
# Package 10101: cotton
# Package 10201: cpbmapi
# Package 10301: cratesmirror
# Package 10401: cronfed
# Package 10501: cryptodrive
# Package 10601: cs.mailutils
# Package 10701: csv
# Package 10801: ctypes-opencv
# Package 10901: cubicweb-pyramid
# Package 11001: currencies
# Package 11101: cx_OracleDBATools
# Package 11201: cythrust
# Package 11301: damn-py
# Package 11401: databox
# Package 11501: DataPrint
# Package 11601: DateTime
# Package 11701: dbmake
# Package 11801: de422
# Package 11901: decutils
# Package 12001: delicious2fluid
# Package 12101: deployrecipes
# Package 12201: devflow
# Package 12301: dhp
# Package 12401: diepy
# Package 12501: ding
# Package 12601: diskimage-builder
# Package 12701: ditail
# Package 12801: django-activity-stream
# Package 12901: django-admin-user-stats
# Package 13001: django-analytical
# Package 13101: django-assetfiles
# Package 13201: django-autoroot
# Package 13301: django-beautifulpredicates
# Package 13401: django-bootstrap9
# Package 13501: django-cached-field
# Package 13601: django-ccsitemaps
# Package 13701: django-ckeditor-enhanced
# Package 13801: djangocms-gmaps
# Package 13901: djangocodemirror
# Package 14001: django-confirmaction
# Package 14101: django-courseaffils
# Package 14201: django-custom-anonymous
# Package 14301: django-db-pool
# Package 14401: django-devtools
# Package 14501: django-dowser
# Package 14601: django-easy-thumbnails-watermark
# Package 14701: django-encode
# Package 14801: django-export-xls
# Package 14901: django-fastcart
# Package 15001: django-fitbit
# Package 15101: django-formview
# Package 15201: django-gcm-android-ios
# Package 15301: django-globals
# Package 15401: django-handlebars
# Package 15501: django-hs-sessions
# Package 15601: django-imagequery
# Package 15701: django-invoicing
# Package 15801: django-js-reverse
# Package 15901: django-layar
# Package 16001: django-livevalidation
# Package 16101: django-mailgun
# Package 16201: django-material
# Package 16301: django-metro-tiny
# Package 16401: django-modelqueryform
# Package 16501: django-multilingual-news
# Package 16601: django-newcache
# Package 16701: django-oauth-toolkit-hup
# Package 16801: django-organice-theme-fullpage
# Package 16901: django-pariah
# Package 17001: django-pgmp
# Package 17101: django-polarize
# Package 17201: django-profile
# Package 17301: djangopypi
# Package 17401: django-ratelimit2
# Package 17501: django-registration-py3
# Package 17601: django-restart
# Package 17701: django-reusableapps
# Package 17801: django-s3-cache
# Package 17901: django-sekh
# Package 18001: django-setuptest-recipe
# Package 18101: django-simple-blog
# Package 18201: django-site-settings
# Package 18301: django_social_followers
# Package 18401: django_sql_dashboards
# Package 18501: django-static-pages
# Package 18601: django-sunset
# Package 18701: django-tastypie-extendedmodelresource
# Package 18801: django-test-autocomplete
# Package 18901: django-time-logger
# Package 19001: django-trello-broker
# Package 19101: django-unsubscribe
# Package 19201: django-usertools
# Package 19301: django-virtualssi
# Package 19401: django_weibo
# Package 19501: django-yaaac
# Package 19601: djcities
# Package 19701: djmicrosip_actualizarcosto
# Package 19801: djstopie
# Package 19901: dm.zdoc
# Package 20001: docgrep
# Package 20101: docker-volume
# Package 20201: dogepy
# Package 20301: Domo
# Package 20401: dottedish
# Package 20501: dr
# Package 20601: drf-nested-resources
# Package 20701: dry-rest-permissions
# Package 20801: duckduckpy
# Package 20901: DVDev
# Package 21001: dynpy
# Package 21101: EasyFrames
# Package 21201: ebas-uploader
# Package 21301: ecsminion
# Package 21401: edrnsite.content
# Package 21501: egenix-mx-base
# Package 21601: ElasticTabstops
# Package 21701: elsec
# Package 21801: emogenerator
# Package 21901: enigma
# Package 22001: envparse
# Package 22101: epytext2rst
# Package 22201: esFrontLine
# Package 22301: etm_qt
# Package 22401: eventize-expect
# Package 22501: excelcsv
# Package 22601: experimental.portalfactoryfix
# Package 22701: eyeD3-pip
# Package 22801: fabric-aws-tools
# Package 22901: factoryboy-gaendb
# Package 23001: fantail
# Package 23101: fastxor
# Package 23201: featureforge
# Package 23301: FErari
# Package 23401: figgler
# Package 23501: filewatch
# Package 23601: fio_carrier_pricelist
# Package 23701: firstPy
# Package 23801: flake8-blind-except
# Package 23901: flask-app-router
# Package 24001: Flask-Compress-nondebug
# Package 24101: Flask-Fundatio
# Package 24201: Flask-Json-Syslog
# Package 24301: Flask-Negotiate
# Package 24401: flask_replicated
# Package 24501: Flask-Sixpack
# Package 24601: flask-utils
# Package 24701: flexx
# Package 24801: fluentcms-link
# Package 24901: focus
# Package 25001: formatclass
# Package 25101: foxy
# Package 25201: freecad_dist
# Package 25301: frigg-runner
# Package 25401: FTP-pocetnik
# Package 25501: fuckit
# Package 25601: funky
# Package 25701: fxa-python-client
# Package 25801: gale
# Package 25901: garment
# Package 26001: gcm-client
# Package 26101: Gelatin
# Package 26201: genpipeline
# Package 26301: Geohash
# Package 26401: gerencianet
# Package 26501: get_some_danmaku
# Package 26601: ghizmo
# Package 26701: gisgroup-statbank
# Package 26801: githook
# Package 26901: gitolite-manager
# Package 27001: gitzebo
# Package 27101: globussh
# Package 27201: gnome-shell-search-fedora-packages
# Package 27301: gocept.objectquery
# Package 27401: gomill
# Package 27501: GoogleScholar
# Package 27601: gpg-inline
# Package 27701: grafana_api_client
# Package 27801: GraphPath
# Package 27901: Greg
# Package 28001: GroopM
# Package 28101: gsw2001
# Package 28201: gumbo
# Package 28301: habitican_curse
# Package 28401: Hammertime
# Package 28501: happy
# Package 28601: hate
# Package 28701: headhunter
# Package 28801: hellanzb
# Package 28901: hesiod53
# Package 29001: hgpaste
# Package 29101: hiredis
# Package 29201: hn
# Package 29301: hopla
# Package 29401: hotworker
# Package 29501: htmlcontact
# Package 29601: httpheader
# Package 29701: hulu
# Package 29801: hwm
# Package 29901: hypothesis-numpy
# Package 30001: icapclient
# Package 30101: idict
# Package 30201: iii
# Package 30301: imagestore
# Package 30401: impermium
# Package 30501: incywincy
# Package 30601: infi.projector
# Package 30701: iniconfig
# Package 30801: insight-bertrpc
# Package 30901: internal_links
# Package 31001: invisibleroads-repositories
# Package 31101: ipernity_api
# Package 31201: ipython_doctester
# Package 31301: isbnid
# Package 31401: isotoma.recipe.squid
# Package 31501: itsbroken
# Package 31601: j01.form
# Package 31701: japanese_holiday
# Package 31801: jaychou
# Package 31901: jfi
# Package 32001: jira-cycle-extract
# Package 32101: joblib
# Package 32201: jps_plot
# Package 32301: js.dynatree
# Package 32401: js.jqueryui_tagit
# Package 32501: jsongit
# Package 32601: json-sempai
# Package 32701: js.videojs
# Package 32801: jupyter_core
# Package 32901: jycat
# Package 33001: kambo
# Package 33101: keepass
# Package 33201: keyserver-ng
# Package 33301: kids.xml
# Package 33401: KKKr
# Package 33501: kola
# Package 33601: kotti_theme_slate
# Package 33701: ks.smartimage
# Package 33801: kyper.data
# Package 33901: langchangetrack
# Package 34001: latimes-qiklog
# Package 34101: lazypy
# Package 34201: leanpub
# Package 34301: lemon-filebrowser
# Package 34401: letsencrypt-compatibility-test
# Package 34501: libBGG
# Package 34601: LibQutrub
# Package 34701: lie_to_me
# Package 34801: lineid_plot
# Package 34901: lint381
# Package 35001: list_fun
# Package 35101: livescrape
# Package 35201: loads
# Package 35301: logfilter
# Package 35401: logstats
# Package 35501: loupe
# Package 35601: lsptf
# Package 35701: lurklib
# Package 35801: m2websocket
# Package 35901: MACS2
# Package 36001: mail1
# Package 36101: make-it-easy
# Package 36201: Manifold
# Package 36301: MARDS
# Package 36401: markview
# Package 36501: mateo457_ch2_practice
# Package 36601: maxixe
# Package 36701: md2remark
# Package 36801: MechanicalSoup
# Package 36901: mega.py
# Package 37001: memoto
# Package 37101: meshparser
# Package 37201: metaq
# Package 37301: mext.context
# Package 37401: MIBEL_Downloader
# Package 37501: micropython-imaplib
# Package 37601: microsoft
# Package 37701: mine
# Package 37801: minitage.recipe.egg
# Package 37901: miura
# Package 38001: mltoolkit
# Package 38101: mockldap
# Package 38201: modred
# Package 38301: momentpy
# Package 38401: mongo-mail-server
# Package 38501: monolithe
# Package 38601: Mopidy-Notifier
# Package 38701: mosquitto
# Package 38801: mozdebug
# Package 38901: mprint
# Package 39001: mr.sisyphus
# Package 39101: mucor
# Package 39201: multiprocessing_on_dill
# Package 39301: MUSiCC
# Package 39401: my315ok.portlet.logo
# Package 39501: myMath
# Package 39601: mysqldbhelper
# Package 39701: nagios-mesos-service-check
# Package 39801: nanpy
# Package 39901: nbupload
# Package 40001: nefertari_sqla
# Package 40101: nestCecil
# Package 40201: nester_gangzhang
# Package 40301: nester_splendour
# Package 40401: netdisk
# Package 40501: networking-sfc
# Package 40601: newsParser
# Package 40701: ngi.site.notification
# Package 40801: nimbstor
# Package 40901: nnsearch
# Package 41001: noody-utils
# Package 41101: NoseJS
# Package 41201: NoseXUnitLite
# Package 41301: nozama-cloudsearch-data
# Package 41401: ntracer
# Package 41501: nusbot
# Package 41601: OAM
# Package 41701: observed
# Package 41801: odoo-data
# Package 41901: oidc
# Package 42001: omnigraffle-export
# Package 42101: online-array
# Package 42201: openaps-contrib
# Package 42301: openerp-base-action-rule
# Package 42401: openerp-marketing-campaign
# Package 42501: OpenGlider
# Package 42601: openmm
# Package 42701: opentracing_instrumentation
# Package 42801: optparse_gui
# Package 42901: ore.xapian
# Package 43001: osf
# Package 43101: osx-powerline-battery-segment
# Package 43201: ovr
# Package 43301: p4a.calendar
# Package 43401: padlock
# Package 43501: palpatine
# Package 43601: pantsbuild.pants
# Package 43701: paramSeeker
# Package 43801: participationgraphs
# Package 43901: pasture
# Package 44001: paylib
# Package 44101: pcommerce.multilanguagefields
# Package 44201: pdfserenitynow
# Package 44301: Peeper
# Package 44401: pennyblack
# Package 44501: persistent_crypto_dict
# Package 44601: PGeoTRMM
# Package 44701: phen
# Package 44801: phytab_splitter
# Package 44901: PieCrust-WordpressSQL
# Package 45001: pimpmytheme
# Package 45101: pion
# Package 45201: PIPS
# Package 45301: pizza_auth
# Package 45401: plantextract
# Package 45501: p_list
# Package 45601: plone.app.transmogrifier
# Package 45701: plone.recipe.plone
# Package 45801: plonetheme.keepitsimple
# Package 45901: plpydbapi
# Package 46001: pmock
# Package 46101: pojson
# Package 46201: ponly
# Package 46301: portier
# Package 46401: powergama
# Package 46501: Praba
# Package 46601: prestans
# Package 46701: printEverInList
# Package 46801: probebase
# Package 46901: Products.BastionZenoss
# Package 47001: Products.FileSystemSite
# Package 47101: Products.PermissionComprehensible
# Package 47201: Products.republisher
# Package 47301: Products.ZSPARQLMethod
# Package 47401: proof
# Package 47501: proxyapi
# Package 47601: pssh
# Package 47701: PublicNotificationsPlugin
# Package 47801: punter_cli
# Package 47901: pvWebMonitor
# Package 48001: py3minepi
# Package 48101: pyafraid
# Package 48201: py-applescript
# Package 48301: pybald-routes
# Package 48401: pybkick
# Package 48501: pybuilder_header_plugin
# Package 48601: pycdio
# Package 48701: pyCLI
# Package 48801: pyConditions
# Package 48901: pycrates
# Package 49001: pydap.handlers.proxy
# Package 49101: pydeps
# Package 49201: pydocxs3upload
# Package 49301: pyebook
# Package 49401: pyespeak
# Package 49501: pyf.components.consumers.csvwriter
# Package 49601: pyflowdock
# Package 49701: pygame_cffi
# Package 49801: pygi-gio-coroutines
# Package 49901: py-goldsberry
# Package 50001: pyGTrends
# Package 50101: pyhoe
# Package 50201: pyinklevel
# Package 50301: pyjld.os
# Package 50401: pykml
# Package 50501: pylfu
# Package 50601: PyLit-Project
# Package 50701: pylygon
# Package 50801: pymcmc
# Package 50901: pymlx
# Package 51001: pymstache
# Package 51101: pyndfd
# Package 51201: Pynoramio
# Package 51301: pyobjcryst
# Package 51401: py-optimus
# Package 51501: py-pattern-matching
# Package 51601: pypi-alias
# Package 51701: PyPM
# Package 51801: pyproject
# Package 51901: pyqq
# Package 52001: pyramid_authsanity
# Package 52101: pyramid_localize
# Package 52201: pyramid_sqlalchemy
# Package 52301: pyrecon
# Package 52401: pyrl
# Package 52501: pyRXP
# Package 52601: pysd
# Package 52701: PySignalHound
# Package 52801: pysnmp
# Package 52901: pysprints
# Package 53001: pyStopWatch
# Package 53101: pytagcloud
# Package 53201: pytest_click
# Package 53301: pytest-pep257
# Package 53401: pythemis
# Package 53501: python-aspects
# Package 53601: python-ceilometerclient
# Package 53701: python-ddp
# Package 53801: python-eunuchs
# Package 53901: python-google-option-chain
# Package 54001: python-josso-auth
# Package 54101: python-louvain
# Package 54201: python-nagios-helpers
# Package 54301: python-pandora
# Package 54401: python-radix
# Package 54501: python-simple-hipchat
# Package 54601: python-syncope
# Package 54701: python_util_thanq
# Package 54801: python-zonediff
# Package 54901: PyTransit
# Package 55001: pyunicorn
# Package 55101: pyvenny
# Package 55201: pywatson
# Package 55301: PyWMOFiles
# Package 55401: pyxval
# Package 55501: qdatum
# Package 55601: qnpct
# Package 55701: quality_report
# Package 55801: QuickCommand
# Package 55901: quiver
# Package 56001: radarsatlib
# Package 56101: Rakun
# Package 56201: rapidpro-expressions
# Package 56301: raptus.princexml
# Package 56401: rawgithub
# Package 56501: rdc.etl
# Package 56601: readme_renderer
# Package 56701: Rect
# Package 56801: redis-file
# Package 56901: redpackets
# Package 57001: refline.srccheck
# Package 57101: releaser
# Package 57201: renderthreads
# Package 57301: repoze.lemonade
# Package 57401: requepl
# Package 57501: rer.portlet.advanced_static
# Package 57601: RestfulClient
# Package 57701: retrypy
# Package 57801: rgwadmin
# Package 57901: ringing-lib
# Package 58001: rmb
# Package 58101: robotframework-imagehorizonlibrary
# Package 58201: rod.recipe.ejabberd
# Package 58301: rosendale
# Package 58401: rpip
# Package 58501: rss2sn
# Package 58601: rt.simpleslider
# Package 58701: runjop
# Package 58801: S3Backup
# Package 58901: safeJSON
# Package 59001: samklang-menu
# Package 59101: sasa
# Package 59201: sbo-templates
# Package 59301: schachtelier
# Package 59401: scikit-fusion
# Package 59501: score.dbgsrv
# Package 59601: scrapy-inline-requests
# Package 59701: scrubber
# Package 59801: seam
# Package 59901: se-django-empty
# Package 60001: semantic_web_pygments
# Package 60101: sentry-heroku
# Package 60201: Sergent
# Package 60301: setupext-gitversion
# Package 60401: sge-pygame
# Package 60501: shebang
# Package 60601: shinkenplugins.plugins.graphite_api
# Package 60701: shove-memcache
# Package 60801: sigma.standard
# Package 60901: silva.pas.openid
# Package 61001: simple_comet
# Package 61101: SimpleLogger
# Package 61201: simpletag
# Package 61301: singleton_factory
# Package 61401: sj2psi
# Package 61501: skyline
# Package 61601: slapos.tool.nosqltester_manager
# Package 61701: slimmer
# Package 61801: smartcache
# Package 61901: smooch
# Package 62001: snapbill
# Package 62101: sobertest
# Package 62201: solar
# Package 62301: Sorrex
# Package 62401: spambayes-lite
# Package 62501: specpy
# Package 62601: sphinxcontrib-cqlengine
# Package 62701: sphinxcontrib-smblink
# Package 62801: sphinxtheme.readability
# Package 62901: splicetee
# Package 63001: sprinkles
# Package 63101: sPyte
# Package 63201: sql_cache
# Package 63301: squidpeek
# Package 63401: ssh_scanner
# Package 63501: stack-watcher
# Package 63601: stathat-async
# Package 63701: steamweb
# Package 63801: stockpyle
# Package 63901: strata
# Package 64001: strippers.mixi
# Package 64101: stylize
# Package 64201: suchmaschine
# Package 64301: Superdesk-Core
# Package 64401: svargaext.sqlamigrate
# Package 64501: swehockey
# Package 64601: SyFi
# Package 64701: SysExtension
# Package 64801: tablist
# Package 64901: takai
# Package 65001: taras.django.fields
# Package 65101: tastypie-msgpack
# Package 65201: tddspry
# Package 65301: telemetron-client
# Package 65401: tempodb-pandas
# Package 65501: TermRecord
# Package 65601: testing.elasticsearch
# Package 65701: tet.fanstatic
# Package 65801: tfd
# Package 65901: TGSociable
# Package 66001: TheZine
# Package 66101: thrift_hive_metastore
# Package 66201: tiddlywebplugins.atom
# Package 66301: TiffCapture
# Package 66401: TimeSide
# Package 66501: tinyschachtler
# Package 66601: tkScenarist
# Package 66701: tngems-sovereign
# Package 66801: tomcom.plone.base
# Package 66901: torch_model_client
# Package 67001: tornado-stripe
# Package 67101: tourbillon
# Package 67201: TracDeveloper
# Package 67301: TracPrivateTickets
# Package 67401: transdate
# Package 67501: trclient
# Package 67601: tri.form
# Package 67701: try_catch
# Package 67801: trytond_health_nursing
# Package 67901: trytonpsk_reports
# Package 68001: tt_sass
# Package 68101: turnip
# Package 68201: tw2.jqplugins.elrte
# Package 68301: twentytab-model-to-bidimensional
# Package 68401: twitchwatcher
# Package 68501: tw.jsunit
# Package 68601: txctools
# Package 68701: txsocksx
# Package 68801: typing
# Package 68901: ucnumber
# Package 69001: ulit
# Package 69101: unice.portlet.telechargement
# Package 69201: unittest-tap-reporting
# Package 69301: updatedir
# Package 69401: urlimport.py
# Package 69501: userconfig
# Package 69601: uvs_utils
# Package 69701: ValidationLib
# Package 69801: vbihmm
# Package 69901: vedro
# Package 70001: vesna-alhauthproxy
# Package 70101: Vinergy
# Package 70201: visage
# Package 70301: vmonere
# Package 70401: vpnc
# Package 70501: vxapi
# Package 70601: wagtail-stacks-embed
# Package 70701: warnup
# Package 70801: wbpy
# Package 70901: webcleaner
# Package 71001: webpage
# Package 71101: Webware
# Package 71201: wfw
# Package 71301: WHIPS
# Package 71401: wikipediabase
# Package 71501: Wintx
# Package 71601: wnyc_backup
# Package 71701: WorkingHours
# Package 71801: wretch
# Package 71901: wsgi-static
# Package 72001: wutu
# Package 72101: xbob.db.biosecurid.face
# Package 72201: xetracker
# Package 72301: XmarcosCrawler
# Package 72401: xmsgs-tools
# Package 72501: XStatic-Angular-Animate
# Package 72601: xvarnish-python
# Package 72701: yagmail
# Package 72801: Yapil
# Package 72901: yelp-api-client
# Package 73001: YoudaoDict
# Package 73101: yweather
# Package 73201: z3c.persistentfactory
# Package 73301: ZacNester
# Package 73401: zclient
# Package 73501: zebra
# Package 73601: zettwerk.fullcalendar
# Package 73701: zinspect
# Package 73801: zojax.mr.gae
# Package 73901: zope.app.testing
# Package 74001: zope.schema
# Package 74101: zrpc
# Package 74201: zz
#              package     requirement package_name package_version
# 0  02exercicio-1.0.0             NaN  02exercicio           1.0.0
# 1    0x10c-asm-0.0.2             NaN    0x10c-asm           0.0.2
# 2   115wangpan-0.7.6  beautifulsoup4   115wangpan           0.7.6
# 3   115wangpan-0.7.6          homura   115wangpan           0.7.6
# 4   115wangpan-0.7.6        humanize   115wangpan           0.7.6

# %%
# Save to file
df.to_csv('requirements.csv', index=False)

# %%
print(df.loc[df.requirement.notnull(), 'package'].unique().size)
# Out:
# 20642

# %% [markdown]
# # Base dependencies
#
# I have now parsed the formal dependencies for 20642 python packages. However, some of those dependencies themselves have dependencies. Let's go ahead and find the base dependency. I will find all of the requirements that each requirements itself has, and keep going until there are no new dependencies.
#
# ## Difficulties:
#
# 1. Cyclic dependencies: astropy requires wcs_axes, which itself requires astropy. Therefore a naive recursive solution will never end. I use a Tree class that keeps track of what has already been searched to avoid infinite loops.

# %%
class Tree(object):
    def __init__(self, name):
        self.name = name
        self.children = []
        return

    def __contains__(self, obj):
        return obj == self.name or any([obj in c for c in self.children])
    
    def add(self, obj):
        if not self.__contains__(obj):
            self.children.append(Tree(obj))
            return True
        return False
    
    def get_base_requirements(self):
        base = []
        for child in self.children:
            if len(child.children) == 0:
                base.append(child.name)
            else:
                for b in [c.get_base_requirements() for c in child.children()]:
                    base.extend(b)
        return np.unique(base)
    

def get_requirements(package):
    return df.loc[(df.package_name == package) & (df.requirement.notnull()), 'requirement'].values


def get_dependency_tree(package, tree):
    reqs = get_requirements(package)
    for req in reqs:
        #print(req)
        flg = tree.add(req)
        if not flg:
            continue
        tree = get_base_dependencies(req, tree)
    return tree

# %%
p = '115wangpan'
p = 'astroquery'
get_dependency_tree(p, Tree(p)).get_base_requirements()
# Out:
# array(['.', 'astropy', 'astropy-helpers', 'astropy_helpers', 'cython',
#        'decorator', 'flask', 'httpbin', 'itsdangerous', 'markupsafe',
#        'matplotlib', 'numpy', 'py', 'pytest', 'pytest-cov',
#        'pytest-httpbin', 'pyyaml', 'regendoc', 'requests', 'six', 'sphinx',
#        'sphinx-py3doc-enhanced-theme', 'wcsaxes', 'wheel'],
#       dtype='|S28')

# %%
datadict = defaultdict(list)
for i, package in enumerate(df.package_name.unique()):
    if i % 100 == 0:
        print('Package {}: {}'.format(i+1, package))
    try:
        deptree = get_dependency_tree(package, Tree(package))
    except:
        print('Failure getting base dependencies for {}'.format(package))
        raise ValueError
    for dependency in deptree.get_base_requirements():
        datadict['package_name'].append(package)
        datadict['requirements'].append(dependency)

base_df = pd.DataFrame(data=datadict)
base_df.head()
# Out:
# Package 1: 02exercicio
# Package 101: aboutyou
# Package 201: adagios
# Package 301: Aduro
# Package 401: agon-ratings
# Package 501: aiohttp_mako
# Package 601: ajenti.plugin.auth-users
# Package 701: aldryn-tours
# Package 801: allmychanges
# Package 901: amitgroup
# Package 1001: AndroidResR
# Package 1101: antidogpiling
# Package 1201: apidev-sanza
# Package 1301: appomatic_autocomplete
# Package 1401: archetypes.recurringdate
# Package 1501: argvee
# Package 1601: arts
# Package 1701: aspose_words_java_for_python
# Package 1801: asymm-enum
# Package 1901: atomisator.outputs
# Package 2001: authentic2-idp-freshdesk
# Package 2101: autoprefixer
# Package 2201: awesome-package
# Package 2301: azure-batch-apps
# Package 2401: badgermole
# Package 2501: bancommons
# Package 2601: bash-toolbelt
# Package 2701: bcdoc
# Package 2801: Beautils
# Package 2901: berry_module
# Package 3001: bibos_utils
# Package 3101: biocma
# Package 3201: bitfile
# Package 3301: blender-bam
# Package 3401: bluebream
# Package 3501: Boodler
# Package 3601: BotParse
# Package 3701: boxup_core
# Package 3801: bridgedb
# Package 3901: bst.pygasus.datamanager
# Package 4001: buildbot-gitlab
# Package 4101: burrow
# Package 4201: c2.app.shorturl
# Package 4301: caf
# Package 4401: canary
# Package 4501: carrier
# Package 4601: catzzz
# Package 4701: celcius
# Package 4801: cesiumpy
# Package 4901: chan
# Package 5001: checkfort
# Package 5101: chessmind.grok
# Package 5201: chronos-python
# Package 5301: citelementtree
# Package 5401: classdirectory
# Package 5501: click-utils
# Package 5601: closure-soy
# Package 5701: cloudy-release-client
# Package 5801: cmonkey
# Package 5901: cmsplugin-search
# Package 6001: codalib
# Package 6101: coinbase
# Package 6201: collective.catalogexport
# Package 6301: collective.formwidget.mathjax
# Package 6401: collective.keywordcondition
# Package 6501: collective.portlet.keywordmatches
# Package 6601: collective.rtvideo.metacafe
# Package 6701: Collectors
# Package 6801: CommandTool
# Package 6901: concoord
# Package 7001: confluence
# Package 7101: contender
# Package 7201: coopr.environ
# Package 7301: COS
# Package 7401: cozy-indexer
# Package 7501: CreateCloudMap
# Package 7601: crox
# Package 7701: csputils
# Package 7801: ctf-cli
# Package 7901: cubicweb-medicalexp
# Package 8001: curling
# Package 8101: cyclops_tmanager
# Package 8201: daemonic
# Package 8301: DataAPI
# Package 8401: dataset-model
# Package 8501: dbaas-aclapi
# Package 8601: ddlgenerator
# Package 8701: DeepCL
# Package 8801: demo-package
# Package 8901: detox
# Package 9001: dic
# Package 9101: digitalnz
# Package 9201: displays
# Package 9301: django-absolute
# Package 9401: django-admin-multiselect
# Package 9501: django-allowedsites
# Package 9601: django-assets-toolkit
# Package 9701: Django-Avocado
# Package 9801: django-bingo
# Package 9901: django-braintree
# Package 10001: django-cas-client
# Package 10101: djangochurch-contact
# Package 10201: djangocms-highlightjs
# Package 10301: django-command-interface
# Package 10401: django-contextlayers
# Package 10501: django-cssmin
# Package 10601: django_dbdev
# Package 10701: django-devotionals
# Package 10801: django-drift
# Package 10901: django-elastimorphic
# Package 11001: django-epic
# Package 11101: django-facebook-comments
# Package 11201: django-file-repository
# Package 11301: django-formrenderingtools
# Package 11401: djangogcal
# Package 11501: django-GNU-Terry-Pratchett
# Package 11601: django-hbs-makemessages
# Package 11701: django_i18n_attrhelpers
# Package 11801: django-inlineobjects
# Package 11901: django-jquery
# Package 12001: django-kvstore
# Package 12101: django-livechat
# Package 12201: django-mailer-throttled
# Package 12301: django-matome
# Package 12401: django-mindscape
# Package 12501: django-mongoengine-forms
# Package 12601: django-navbar
# Package 12701: django-nsa
# Package 12801: django-oracle-drcp
# Package 12901: django-parser
# Package 13001: django-photologue-praekelt
# Package 13101: django-postgres-dbdefaults
# Package 13201: django-publisher
# Package 13301: django-radagast
# Package 13401: django-registration-extended-backend
# Package 13501: django-rest-encrypted-lookup
# Package 13601: django-revuo
# Package 13701: djangosaml2-dj16
# Package 13801: django-sentry
# Package 13901: django-shop-saferpay
# Package 14001: django-simple-settings
# Package 14101: django-sms-support
# Package 14201: django-sqlcipher
# Package 14301: django-statistic
# Package 14401: django-sympa
# Package 14501: django-templatefield
# Package 14601: django-thermostat
# Package 14701: django-trackstats
# Package 14801: django-unique-submission
# Package 14901: django-userthemes
# Package 15001: django-vkontakte-api
# Package 15101: django-winds
# Package 15201: django-zencoder
# Package 15301: djinn
# Package 15401: djsubdomains
# Package 15501: dnd
# Package 15601: docker-psychic
# Package 15701: docx
# Package 15801: domestos
# Package 15901: dougal
# Package 16001: drest
# Package 16101: Drum
# Package 16201: dukaan
# Package 16301: DynamicMachine
# Package 16401: easy-date
# Package 16501: ebicsPy
# Package 16601: edgedb
# Package 16701: ejson
# Package 16801: ella_toolkit
# Package 16901: emoji-ipython-magic
# Package 17001: entropy
# Package 17101: epostkr
# Package 17201: esimport
# Package 17301: eutester
# Package 17401: exabgp
# Package 17501: exportrecipe
# Package 17601: faafo
# Package 17701: factcheck
# Package 17801: FaoFao
# Package 17901: fb-re2
# Package 18001: feincms-extensions
# Package 18101: figment
# Package 18201: findagg
# Package 18301: fio_shipping_ups
# Package 18401: fixtureload
# Package 18501: flask-apps
# Package 18601: flask-daapserver
# Package 18701: Flask-Gravatar
# Package 18801: Flask-Manifest
# Package 18901: Flask-Pushjack
# Package 19001: Flask-Sijax
# Package 19101: Flask-Via
# Package 19201: FLiP
# Package 19301: flylog
# Package 19401: forgetmenot
# Package 19501: fp-growth
# Package 19601: freesms
# Package 19701: fsnav
# Package 19801: funcache
# Package 19901: fuzzysearch
# Package 20001: galaxy-sdk-python
# Package 20101: Gavagai
# Package 20201: gds-nagios-plugins
# Package 20301: genipe
# Package 20401: geojoin
# Package 20501: getent
# Package 20601: gfycat
# Package 20701: gipsy-modeltranslation-sections
# Package 20801: github-cli
# Package 20901: git-restack
# Package 21001: glerbl
# Package 21101: gnoduino
# Package 21201: gocept.zcapatch
# Package 21301: google_embed
# Package 21401: gpgpass
# Package 21501: granoloader
# Package 21601: great-sitemap-search
# Package 21701: ground-soil
# Package 21801: gtwisted
# Package 21901: h5pom
# Package 22001: hamster-bridge
# Package 22101: hash_ring
# Package 22201: hdrhistogram
# Package 22301: hello-greeting-test
# Package 22401: heywood
# Package 22501: hipachectl
# Package 22601: HNComments
# Package 22701: horizon_contrib
# Package 22801: hst
# Package 22901: httpcache
# Package 23001: humanize
# Package 23101: Hydro
# Package 23201: ibm_db_py3
# Package 23301: IDUtils
# Package 23401: imagefacts
# Package 23501: impaf
# Package 23601: indexiterator
# Package 23701: infi.win32service
# Package 23801: inotifyx
# Package 23901: interlude
# Package 24001: iodine
# Package 24101: ipv4toipv6
# Package 24201: ironic-python-agent
# Package 24301: isoweek
# Package 24401: iw_parse
# Package 24501: jaraco.text
# Package 24601: jeon
# Package 24701: jirafs_list_table
# Package 24801: JoeLogTools
# Package 24901: jsc
# Package 25001: jsl
# Package 25101: jsonmerge
# Package 25201: jsonv
# Package 25301: junction
# Package 25401: kabuki
# Package 25501: kdcproxy
# Package 25601: keystone-crux
# Package 25701: kippt
# Package 25801: kofconfig
# Package 25901: kroman
# Package 26001: kwplayer
# Package 26101: lars
# Package 26201: lazycat
# Package 26301: leap_gwas
# Package 26401: leonardo-celery
# Package 26501: lgapontes
# Package 26601: librato-metrics
# Package 26701: lightqueue
# Package 26801: Linktastic
# Package 26901: listenclosely-telegram
# Package 27001: lltk
# Package 27101: logbook-zmqpush
# Package 27201: logstats
# Package 27301: lpjsmin
# Package 27401: lumberjill
# Package 27501: m3-kladr
# Package 27601: MagicFolder
# Package 27701: makeCourse
# Package 27801: mapcode
# Package 27901: MarkdownTools2
# Package 28001: matchbox
# Package 28101: mbuild
# Package 28201: mdx_collapse
# Package 28301: medularis-django-utils
# Package 28401: memsink
# Package 28501: metacorus-django-utils
# Package 28601: metricfactory
# Package 28701: mhctools
# Package 28801: micropython-libc
# Package 28901: mifare-view-dump
# Package 29001: mining
# Package 29101: mixpanel_gevent_proxy
# Package 29201: moarjson
# Package 29301: modoboa
# Package 29401: monarchcontroller
# Package 29501: mongoquery
# Package 29601: moogli
# Package 29701: mortar-api-python
# Package 29801: mozfile
# Package 29901: mqtt-randompub
# Package 30001: mtg-ssm
# Package 30101: multiquery
# Package 30201: mutter
# Package 30301: mylit
# Package 30401: n2cw
# Package 30501: nametrans
# Package 30601: NCPlugin
# Package 30701: neomodel
# Package 30801: nester_tk
# Package 30901: networking-odl
# Package 31001: nfg.ideal
# Package 31101: ng.xmlrpcscan
# Package 31201: nmi_mysql
# Package 31301: normalize-easy
# Package 31401: nose-pattern-exclude
# Package 31501: notifydict
# Package 31601: nsxramlclient
# Package 31701: nwanime_dl
# Package 31801: obhm
# Package 31901: odfpy
# Package 32001: Ojota
# Package 32101: onegov.event
# Package 32201: Oort
# Package 32301: openerp-analytic-user-function
# Package 32401: openerp-l10n-uk
# Package 32501: OpenGLContext_qt
# Package 32601: openpay
# Package 32701: oprex
# Package 32801: ore.dtmlview
# Package 32901: oslo.policy
# Package 33001: outlier_utils
# Package 33101: pack64
# Package 33201: Pairtree
# Package 33301: pantsbuild.pants.backend.android
# Package 33401: parguments
# Package 33501: passpie
# Package 33601: payjp
# Package 33701: pdbcs
# Package 33801: pebble-remote
# Package 33901: penpal
# Package 34001: pessimum
# Package 34101: pgtask_worker
# Package 34201: phylmaker
# Package 34301: pigrate
# Package 34401: pingo
# Package 34501: piprot
# Package 34601: plac
# Package 34701: plip
# Package 34801: plone.formwidget.recurrence
# Package 34901: plonetheme.lithium
# Package 35001: plumiftp
# Package 35101: poezio
# Package 35201: pony_monitor
# Package 35301: postboy2
# Package 35401: ppp_oeis
# Package 35501: prestornado
# Package 35601: probe-plotting
# Package 35701: Products.Collage
# Package 35801: Products.PASIPAuth
# Package 35901: Products.TinyMCE
# Package 36001: proofcheck
# Package 36101: pryvate
# Package 36201: PTP
# Package 36301: pumpr
# Package 36401: pwenc
# Package 36501: pyA10_CB
# Package 36601: pyAniSort
# Package 36701: pybankreader
# Package 36801: pyboro
# Package 36901: pyccuweather
# Package 37001: pycmd
# Package 37101: pycountry-nopytest
# Package 37201: pydataframe
# Package 37301: PyDistMesh
# Package 37401: pyecho
# Package 37501: pyexpect
# Package 37601: py-finvoice
# Package 37701: pyGallerid
# Package 37801: pyglot
# Package 37901: pygtaw
# Package 38001: pyHyperV
# Package 38101: pyjama
# Package 38201: pykongregate
# Package 38301: pylichess
# Package 38401: pyltp
# Package 38501: pymessage
# Package 38601: pymorphy2-dicts
# Package 38701: pyndexter
# Package 38801: Pynuts
# Package 38901: Pyomo
# Package 39001: pypaster
# Package 39101: pypid
# Package 39201: PyPR
# Package 39301: pyqode-uic
# Package 39401: pyramid_contextauth
# Package 39501: pyramid_objective
# Package 39601: pyrandint
# Package 39701: pyripple
# Package 39801: pysat
# Package 39901: PyShada
# Package 40001: pysnmp-apps
# Package 40101: pyssim
# Package 40201: pyswitch
# Package 40301: pytest-couchdbkit
# Package 40401: pytest-rerunfailures
# Package 40501: python-active-com-api
# Package 40601: python-builtwith
# Package 40701: python-dhl
# Package 40801: Python-fontconfig
# Package 40901: PythonicTestcase
# Package 41001: python-lunrclient
# Package 41101: python-ntlm-fixed
# Package 41201: python-propeller
# Package 41301: python-shorturl
# Package 41401: python-telegram-bot
# Package 41501: python-wepay
# Package 41601: PyToxme
# Package 41701: py-unrar2
# Package 41801: pyviewx.client
# Package 41901: pywikibot
# Package 42001: pyzap
# Package 42101: qiime-default-reference
# Package 42201: qt_object_viewer
# Package 42301: quickfind
# Package 42401: rabbitman
# Package 42501: rajce_download
# Package 42601: raptor
# Package 42701: rawkit
# Package 42801: rdlm-py
# Package 42901: re-client
# Package 43001: redish
# Package 43101: redtube
# Package 43201: rekall_yara
# Package 43301: renren_client
# Package 43401: repoze.vhm
# Package 43501: requests-middleware
# Package 43601: RestAuth
# Package 43701: retrypy
# Package 43801: rhubarbe
# Package 43901: Rivets
# Package 44001: robotframework-djangolibrary
# Package 44101: roles
# Package 44201: router
# Package 44301: rsdl
# Package 44401: rtstool
# Package 44501: runstat
# Package 44601: s4cmd
# Package 44701: salut
# Package 44801: satella
# Package 44901: sc.base.audioplayer
# Package 45001: scikit-nano
# Package 45101: scour
# Package 45201: scribe_logger
# Package 45301: SDog
# Package 45401: seedmeopenmm
# Package 45501: sendgrid-newsletter
# Package 45601: sentry-wrapper
# Package 45701: seshet
# Package 45801: sge-pygame
# Package 45901: shellvars-py
# Package 46001: shoebill
# Package 46101: SIGACTor
# Package 46201: silva.security.addables
# Package 46301: simplefb
# Package 46401: simplesecuritygroups
# Package 46501: single_process
# Package 46601: skid
# Package 46701: Slang
# Package 46801: slouch
# Package 46901: smilite
# Package 47001: snakeviz
# Package 47101: sockfilter
# Package 47201: sonicLiquidFlux
# Package 47301: spamcheck
# Package 47401: speedtest-cli
# Package 47501: sphinxcontrib-inlinesyntaxhighlight
# Package 47601: sphinxjp.themes.tinkerdahlia
# Package 47701: spliopy
# Package 47801: Spruce-http-common
# Package 47901: SQLAlchemy-Searchable
# Package 48001: squery-lite
# Package 48101: ssmrandom
# Package 48201: stargate
# Package 48301: statx
# Package 48401: stompest
# Package 48501: streamingds
# Package 48601: study
# Package 48701: sudoku-solver
# Package 48801: supervisor_checks
# Package 48901: swagger-stub
# Package 49001: symfit
# Package 49101: tabfileio
# Package 49201: taintedSwallow
# Package 49301: tasbot-spring
# Package 49401: tb-ioc
# Package 49501: teleceptor
# Package 49601: tendenci-videos
# Package 49701: testapp
# Package 49801: tetris_cpp
# Package 49901: tgext.ajaxforms
# Package 50001: themelog
# Package 50101: thriftpy
# Package 50201: tiddlywebplugins.imaker
# Package 50301: Time2Pull
# Package 50401: tinyec
# Package 50501: tkRAD
# Package 50601: toffee
# Package 50701: topp.recipes.opvarnish
# Package 50801: tornado_systemd
# Package 50901: TowerDataApi
# Package 51001: TracLdapPlugin
# Package 51101: transifex
# Package 51201: treestore
# Package 51301: trulia
# Package 51401: trytond_health_inpatient
# Package 51501: trytonpsk_account_voucher
# Package 51601: tuisongbao
# Package 51701: tvrenamer
# Package 51801: twentyc.rpc
# Package 51901: TwitterAPI
# Package 52001: twostream
# Package 52101: txoauth
# Package 52201: TypeQuery
# Package 52301: UcsSdk
# Package 52401: unbound-ec2
# Package 52501: units
# Package 52601: UPDIAN
# Package 52701: URLReader
# Package 52801: UTG
# Package 52901: validate_email
# Package 53001: vcard
# Package 53101: verboselogs
# Package 53201: videoShot
# Package 53301: virtual-less
# Package 53401: vnstaty
# Package 53501: VTIXyTemplate
# Package 53601: wagtail-streamfieldtools
# Package 53701: watchntouch
# Package 53801: webalerts
# Package 53901: WebPattern
# Package 54001: weir
# Package 54101: wheeljack
# Package 54201: wikimapia_api
# Package 54301: wlnm
# Package 54401: worldengine
# Package 54501: wsgi-monitor
# Package 54601: wuxi
# Package 54701: xetracker
# Package 54801: xml-models-redux
# Package 54901: XStatic-Angular-Bootstrap
# Package 55001: xychan
# Package 55101: yamlconf
# Package 55201: ychartspy
# Package 55301: youtube-api-wrapper
# Package 55401: z3c.feature.core
# Package 55501: z3wingdbg
# Package 55601: zc.loggermonitor
# Package 55701: zengine
# Package 55801: zif.xtemplate
# Package 55901: zodbcode
# Package 56001: zope.app.tree
# Package 56101: zope.thread
# Package 56201: zuice
#   package_name    requirements
# 0   115wangpan               .
# 1   115wangpan  beautifulsoup4
# 2   115wangpan          bottle
# 3   115wangpan       decorator
# 4   115wangpan           flaky

# %%
base_df.to_csv('base_requirements.csv', index=False)

# %%
tmp = pd.read_csv('requirements.csv')
print(len(tmp.package_name.unique()))
# Out:
# 56232

# %%
print(len(tmp.loc[tmp.requirement.notnull(), 'package_name'].unique()))
# Out:
# 20522
