# %% [markdown]
# # Fetching Pypi data
# This notebook fetches every package from the pypi server (~74000 packages!), extracts the setup.py and any file or folder with the word 'requirements' in it.

# %%
import xmlrpclib
# only one api server so we'll use the deutschland mirror for downloading
client = xmlrpclib.ServerProxy('http://pypi.python.org/pypi')
packages = client.list_packages()

# %%
import tarfile, re, requests, csv, json
from base64 import b64encode
from kglib.utils.HelperFunctions import ensure_dir
                

def _save_file(pathname, member, tar_file):
    try:
        content = tar_file.extractfile(member).read()
    except:
        return
    
    outfilename = '{}{}'.format(pathname, os.path.basename(member.name))
    ensure_dir(outfilename)
    with open(outfilename, 'w') as outfile:
        outfile.write(content)
    return
                

def _extract_files(package_file, name):
    try:
        tar_file = tarfile.open(fileobj=package_file)
    except:
        return
    for member in tar_file.getmembers():
        if 'setup.py' in member.name or 'requirements' in member.name:
            _save_file(name, member, tar_file)
        #    content = tar_file.extractfile(member).read()
        #    with open('{}{}'.format(name, os.path.basename(member.name)), 'w') as outfile:
        #        outfile.write(content)
        #elif 'requirements' in member.name:
        #    content = tar_file.extractfile(member).read()
        #    with open('{}{}'.format(name, os.path.basename(member.name)), 'w') as outfile:
        #        outfile.write(content)
                
                
def extract_package(name, client=xmlrpclib.ServerProxy('http://pypi.python.org/pypi')):
    for release in client.package_releases(name):
        outdir = 'packages/{}-{}/'.format(name, release)
        doc = client.release_urls(name, release)
        if doc:
            url = None
            for d in doc:
                if d['python_version'] == 'source' and d['url'].endswith('gz'):
                    url = d['url']
            if url:
                #print(doc[3])
                #url = doc[0].get('url')#.replace("http://pypi.python.org/", "http://f.pypi.python.org/")
                #print "Downloading url %s" % url
                req = requests.get(url)
                if req.status_code != 200:
                    print "Could not download file %s" % req.status_code
                else:
                    #print(outdir)
                    ensure_dir('{}'.format(outdir))
                    with open('/tmp/temp_tar', 'w') as tar_file:
                        tar_file.write(req.content)
                    with open('/tmp/temp_tar', 'r') as tar_file:
                        return _extract_files(tar_file, name=outdir)

# %%
ensure_dir('packages')
#for i, package in enumerate(packages[5300+14100+12400+18500:]):
for i, package in enumerate(packages):
    if i % 100 == 0:
        print('Extracting package {} / {}'.format(i+1, len(packages)))
    #print(package)
    
    extract_package(package, client)
# Out:
# Extracting package 1 / 74091
# Extracting package 101 / 74091
# Extracting package 201 / 74091
# Extracting package 301 / 74091
# Extracting package 401 / 74091
# Extracting package 501 / 74091
# Extracting package 601 / 74091
# Extracting package 701 / 74091
# Extracting package 801 / 74091
# Extracting package 901 / 74091
# Extracting package 1001 / 74091
# Extracting package 1101 / 74091
# Extracting package 1201 / 74091
# Extracting package 1301 / 74091
# Extracting package 1401 / 74091
# Extracting package 1501 / 74091
# Extracting package 1601 / 74091
# Extracting package 1701 / 74091
# Extracting package 1801 / 74091
# Extracting package 1901 / 74091
# Extracting package 2001 / 74091
# Extracting package 2101 / 74091
# Extracting package 2201 / 74091
# Extracting package 2301 / 74091
# Extracting package 2401 / 74091
# Extracting package 2501 / 74091
# Extracting package 2601 / 74091
# Extracting package 2701 / 74091
# Extracting package 2801 / 74091
# Extracting package 2901 / 74091
# Extracting package 3001 / 74091
# Extracting package 3101 / 74091
# Extracting package 3201 / 74091
# Extracting package 3301 / 74091
# Extracting package 3401 / 74091
# Extracting package 3501 / 74091
# Extracting package 3601 / 74091
# Extracting package 3701 / 74091
# Extracting package 3801 / 74091
# Could not download file 404
# Extracting package 3901 / 74091
# Extracting package 4001 / 74091
# Extracting package 4101 / 74091
# Extracting package 4201 / 74091
# Extracting package 4301 / 74091
# Extracting package 4401 / 74091
# Extracting package 4501 / 74091
# Extracting package 4601 / 74091
# Extracting package 4701 / 74091
# Extracting package 4801 / 74091
# Extracting package 4901 / 74091
# Extracting package 5001 / 74091
# Extracting package 5101 / 74091
# Extracting package 5201 / 74091
# Extracting package 5301 / 74091
# Extracting package 5401 / 74091
# Extracting package 5501 / 74091
# Extracting package 5601 / 74091
# Extracting package 5701 / 74091
# Extracting package 5801 / 74091
# Extracting package 5901 / 74091
# Extracting package 6001 / 74091
# Extracting package 6101 / 74091
# Extracting package 6201 / 74091
# Extracting package 6301 / 74091
# Extracting package 6401 / 74091
# Extracting package 6501 / 74091
# Extracting package 6601 / 74091
# Extracting package 6701 / 74091
# Extracting package 6801 / 74091
# Extracting package 6901 / 74091
# Extracting package 7001 / 74091
# Extracting package 7101 / 74091
# Extracting package 7201 / 74091
# Extracting package 7301 / 74091
# Extracting package 7401 / 74091
# Extracting package 7501 / 74091
# Extracting package 7601 / 74091
# Extracting package 7701 / 74091
# Extracting package 7801 / 74091
# Extracting package 7901 / 74091
# Extracting package 8001 / 74091
# Extracting package 8101 / 74091
# Extracting package 8201 / 74091
# Extracting package 8301 / 74091
# Extracting package 8401 / 74091
# Extracting package 8501 / 74091
# Extracting package 8601 / 74091
# Extracting package 8701 / 74091
# Extracting package 8801 / 74091
# Extracting package 8901 / 74091
# Extracting package 9001 / 74091
# Extracting package 9101 / 74091
# Extracting package 9201 / 74091
# Extracting package 9301 / 74091
# Extracting package 9401 / 74091
# Extracting package 9501 / 74091
# Extracting package 9601 / 74091
# Extracting package 9701 / 74091
# Extracting package 9801 / 74091
# Extracting package 9901 / 74091
# Extracting package 10001 / 74091
# Extracting package 10101 / 74091
# Extracting package 10201 / 74091
# Extracting package 10301 / 74091
# Extracting package 10401 / 74091
# Extracting package 10501 / 74091
# Extracting package 10601 / 74091
# Extracting package 10701 / 74091
# Extracting package 10801 / 74091
# Extracting package 10901 / 74091
# Extracting package 11001 / 74091
# Extracting package 11101 / 74091
# Extracting package 11201 / 74091
# Extracting package 11301 / 74091
# Extracting package 11401 / 74091
# Extracting package 11501 / 74091
# Extracting package 11601 / 74091
# Extracting package 11701 / 74091
# Extracting package 11801 / 74091
# Extracting package 11901 / 74091
# Extracting package 12001 / 74091
# Extracting package 12101 / 74091
# Extracting package 12201 / 74091
# Extracting package 12301 / 74091
# Extracting package 12401 / 74091
# Extracting package 12501 / 74091
# Extracting package 12601 / 74091
# Extracting package 12701 / 74091
# Extracting package 12801 / 74091
# Extracting package 12901 / 74091
# Extracting package 13001 / 74091
# Extracting package 13101 / 74091
# Extracting package 13201 / 74091
# Extracting package 13301 / 74091
# Extracting package 13401 / 74091
# Extracting package 13501 / 74091
# Extracting package 13601 / 74091
# Extracting package 13701 / 74091
# Extracting package 13801 / 74091
# Extracting package 13901 / 74091
# Extracting package 14001 / 74091
# Extracting package 14101 / 74091
# Extracting package 14201 / 74091
# Extracting package 14301 / 74091
# Extracting package 14401 / 74091
# Extracting package 14501 / 74091
# Extracting package 14601 / 74091
# Extracting package 14701 / 74091
# Extracting package 14801 / 74091
# Extracting package 14901 / 74091
# Extracting package 15001 / 74091
# Extracting package 15101 / 74091
# Extracting package 15201 / 74091
# Extracting package 15301 / 74091
# Extracting package 15401 / 74091
# Extracting package 15501 / 74091
# Extracting package 15601 / 74091
# Extracting package 15701 / 74091
# Extracting package 15801 / 74091
# Extracting package 15901 / 74091
# Extracting package 16001 / 74091
# Extracting package 16101 / 74091
# Extracting package 16201 / 74091
# Extracting package 16301 / 74091
# Extracting package 16401 / 74091
# Extracting package 16501 / 74091
# Extracting package 16601 / 74091
# Extracting package 16701 / 74091
# Extracting package 16801 / 74091
# Extracting package 16901 / 74091
# Extracting package 17001 / 74091
# Extracting package 17101 / 74091
# Extracting package 17201 / 74091
# Extracting package 17301 / 74091
# Extracting package 17401 / 74091
# Extracting package 17501 / 74091
# Extracting package 17601 / 74091
# Extracting package 17701 / 74091
# Extracting package 17801 / 74091
# Extracting package 17901 / 74091
# Extracting package 18001 / 74091
# Extracting package 18101 / 74091
# Extracting package 18201 / 74091
# Extracting package 18301 / 74091
# Extracting package 18401 / 74091
# Extracting package 18501 / 74091
# Extracting package 18601 / 74091
# Extracting package 18701 / 74091
# Extracting package 18801 / 74091
# Extracting package 18901 / 74091
# Extracting package 19001 / 74091
# Extracting package 19101 / 74091
# Extracting package 19201 / 74091
# Extracting package 19301 / 74091
# Extracting package 19401 / 74091
# Extracting package 19501 / 74091
# Extracting package 19601 / 74091
# Extracting package 19701 / 74091
# Extracting package 19801 / 74091
# Extracting package 19901 / 74091
# Extracting package 20001 / 74091
# Extracting package 20101 / 74091
# Extracting package 20201 / 74091
# Extracting package 20301 / 74091
# Extracting package 20401 / 74091
# Extracting package 20501 / 74091
# Extracting package 20601 / 74091
# Extracting package 20701 / 74091
# Extracting package 20801 / 74091
# Extracting package 20901 / 74091
# Extracting package 21001 / 74091
# Extracting package 21101 / 74091
# Extracting package 21201 / 74091
# Extracting package 21301 / 74091
# Extracting package 21401 / 74091
# Extracting package 21501 / 74091
# Extracting package 21601 / 74091
# Extracting package 21701 / 74091
# Extracting package 21801 / 74091
# Extracting package 21901 / 74091
# Extracting package 22001 / 74091
# Extracting package 22101 / 74091
# Extracting package 22201 / 74091
# Extracting package 22301 / 74091
# Extracting package 22401 / 74091
# Extracting package 22501 / 74091
# Extracting package 22601 / 74091
# Extracting package 22701 / 74091
# Extracting package 22801 / 74091
# Extracting package 22901 / 74091
# Extracting package 23001 / 74091
# Extracting package 23101 / 74091
# Extracting package 23201 / 74091
# Extracting package 23301 / 74091
# Extracting package 23401 / 74091
# Extracting package 23501 / 74091
# Extracting package 23601 / 74091
# Extracting package 23701 / 74091
# Extracting package 23801 / 74091
# Extracting package 23901 / 74091
# Extracting package 24001 / 74091
# Extracting package 24101 / 74091
# Extracting package 24201 / 74091
# Extracting package 24301 / 74091
# Extracting package 24401 / 74091
# Extracting package 24501 / 74091
# Extracting package 24601 / 74091
# Extracting package 24701 / 74091
# Extracting package 24801 / 74091
# Extracting package 24901 / 74091
# Extracting package 25001 / 74091
# Extracting package 25101 / 74091
# Extracting package 25201 / 74091
# Extracting package 25301 / 74091
# Extracting package 25401 / 74091
# Extracting package 25501 / 74091
# Extracting package 25601 / 74091
# Extracting package 25701 / 74091
# Extracting package 25801 / 74091
# Extracting package 25901 / 74091
# Extracting package 26001 / 74091
# Extracting package 26101 / 74091
# Extracting package 26201 / 74091
# Extracting package 26301 / 74091
# Extracting package 26401 / 74091
# Extracting package 26501 / 74091
# Extracting package 26601 / 74091
# Extracting package 26701 / 74091
# Extracting package 26801 / 74091
# Extracting package 26901 / 74091
# Extracting package 27001 / 74091
# Extracting package 27101 / 74091
# Extracting package 27201 / 74091
# Extracting package 27301 / 74091
# Extracting package 27401 / 74091
# Extracting package 27501 / 74091
# Extracting package 27601 / 74091
# Extracting package 27701 / 74091
# Extracting package 27801 / 74091
# Extracting package 27901 / 74091
# Extracting package 28001 / 74091
# Extracting package 28101 / 74091
# Extracting package 28201 / 74091
# Extracting package 28301 / 74091
# Extracting package 28401 / 74091
# Extracting package 28501 / 74091
# Extracting package 28601 / 74091
# Extracting package 28701 / 74091
# Extracting package 28801 / 74091
# Extracting package 28901 / 74091
# Extracting package 29001 / 74091
# Extracting package 29101 / 74091
# Extracting package 29201 / 74091
# Extracting package 29301 / 74091
# Extracting package 29401 / 74091
# Extracting package 29501 / 74091
# Extracting package 29601 / 74091
# Extracting package 29701 / 74091
# Extracting package 29801 / 74091
# Extracting package 29901 / 74091
# Extracting package 30001 / 74091
# Extracting package 30101 / 74091
# Extracting package 30201 / 74091
# Extracting package 30301 / 74091
# Extracting package 30401 / 74091
# Extracting package 30501 / 74091
# Extracting package 30601 / 74091
# Extracting package 30701 / 74091
# Extracting package 30801 / 74091
# Extracting package 30901 / 74091
# Extracting package 31001 / 74091
# Extracting package 31101 / 74091
# Extracting package 31201 / 74091
# Extracting package 31301 / 74091
# Extracting package 31401 / 74091
# Extracting package 31501 / 74091
# Extracting package 31601 / 74091
# Extracting package 31701 / 74091
# Extracting package 31801 / 74091
# Extracting package 31901 / 74091
# Extracting package 32001 / 74091
# Extracting package 32101 / 74091
# Extracting package 32201 / 74091
# Extracting package 32301 / 74091
# Extracting package 32401 / 74091
# Extracting package 32501 / 74091
# Extracting package 32601 / 74091
# Extracting package 32701 / 74091
# Extracting package 32801 / 74091
# Extracting package 32901 / 74091
# Extracting package 33001 / 74091
# Extracting package 33101 / 74091
# Extracting package 33201 / 74091
# Extracting package 33301 / 74091
# Extracting package 33401 / 74091
# Extracting package 33501 / 74091
# Extracting package 33601 / 74091
# Extracting package 33701 / 74091
# Extracting package 33801 / 74091
# Extracting package 33901 / 74091
# Extracting package 34001 / 74091
# Extracting package 34101 / 74091
# Extracting package 34201 / 74091
# Extracting package 34301 / 74091
# Extracting package 34401 / 74091
# Extracting package 34501 / 74091
# Extracting package 34601 / 74091
# Extracting package 34701 / 74091
# Extracting package 34801 / 74091
# Extracting package 34901 / 74091
# Extracting package 35001 / 74091
# Extracting package 35101 / 74091
# Extracting package 35201 / 74091
# Extracting package 35301 / 74091
# Extracting package 35401 / 74091
# Extracting package 35501 / 74091
# Extracting package 35601 / 74091
# Extracting package 35701 / 74091
# Extracting package 35801 / 74091
# Extracting package 35901 / 74091
# Extracting package 36001 / 74091
# Extracting package 36101 / 74091
# Extracting package 36201 / 74091
# Extracting package 36301 / 74091
# Extracting package 36401 / 74091
# Extracting package 36501 / 74091
# Extracting package 36601 / 74091
# Extracting package 36701 / 74091
# Extracting package 36801 / 74091
# Extracting package 36901 / 74091
# Extracting package 37001 / 74091
# Extracting package 37101 / 74091
# Extracting package 37201 / 74091
# Extracting package 37301 / 74091
# Extracting package 37401 / 74091
# Extracting package 37501 / 74091
# Extracting package 37601 / 74091
# Extracting package 37701 / 74091
# Extracting package 37801 / 74091
# Extracting package 37901 / 74091
# Extracting package 38001 / 74091
# Extracting package 38101 / 74091
# Extracting package 38201 / 74091
# Extracting package 38301 / 74091
# Extracting package 38401 / 74091
# Extracting package 38501 / 74091
# Extracting package 38601 / 74091
# Extracting package 38701 / 74091
# Extracting package 38801 / 74091
# Extracting package 38901 / 74091
# Extracting package 39001 / 74091
# Extracting package 39101 / 74091
# Extracting package 39201 / 74091
# Extracting package 39301 / 74091
# Extracting package 39401 / 74091
# Extracting package 39501 / 74091
# Extracting package 39601 / 74091
# Extracting package 39701 / 74091
# Extracting package 39801 / 74091
# Extracting package 39901 / 74091
# Extracting package 40001 / 74091
# Extracting package 40101 / 74091
# Extracting package 40201 / 74091
# Extracting package 40301 / 74091
# Extracting package 40401 / 74091
# Extracting package 40501 / 74091
# Extracting package 40601 / 74091
# Extracting package 40701 / 74091
# Extracting package 40801 / 74091
# Extracting package 40901 / 74091
# Extracting package 41001 / 74091
# Extracting package 41101 / 74091
# Extracting package 41201 / 74091
# Extracting package 41301 / 74091
# Extracting package 41401 / 74091
# Extracting package 41501 / 74091
# Extracting package 41601 / 74091
# Extracting package 41701 / 74091
# Extracting package 41801 / 74091
# Extracting package 41901 / 74091
# Extracting package 42001 / 74091
# Extracting package 42101 / 74091
# Extracting package 42201 / 74091
# Extracting package 42301 / 74091
# Extracting package 42401 / 74091
# Extracting package 42501 / 74091
# Extracting package 42601 / 74091
# Extracting package 42701 / 74091
# Extracting package 42801 / 74091
# Extracting package 42901 / 74091
# Extracting package 43001 / 74091
# Extracting package 43101 / 74091
# Extracting package 43201 / 74091
# Extracting package 43301 / 74091
# Extracting package 43401 / 74091
# Extracting package 43501 / 74091
# Extracting package 43601 / 74091
# Extracting package 43701 / 74091
# Extracting package 43801 / 74091
# Extracting package 43901 / 74091
# Extracting package 44001 / 74091
# Extracting package 44101 / 74091
# Extracting package 44201 / 74091
# Extracting package 44301 / 74091
# Extracting package 44401 / 74091
# Extracting package 44501 / 74091
# Extracting package 44601 / 74091
# Extracting package 44701 / 74091
# Extracting package 44801 / 74091
# Extracting package 44901 / 74091
# Extracting package 45001 / 74091
# Extracting package 45101 / 74091
# Extracting package 45201 / 74091
# Extracting package 45301 / 74091
# Extracting package 45401 / 74091
# Extracting package 45501 / 74091
# Extracting package 45601 / 74091
# Extracting package 45701 / 74091
# Extracting package 45801 / 74091
# Extracting package 45901 / 74091
# Extracting package 46001 / 74091
# Extracting package 46101 / 74091
# Extracting package 46201 / 74091
# Extracting package 46301 / 74091
# Extracting package 46401 / 74091
# Extracting package 46501 / 74091
# Extracting package 46601 / 74091
# Extracting package 46701 / 74091
# Extracting package 46801 / 74091
# Extracting package 46901 / 74091
# Extracting package 47001 / 74091
# Extracting package 47101 / 74091
# Extracting package 47201 / 74091
# Extracting package 47301 / 74091
# Extracting package 47401 / 74091
# Extracting package 47501 / 74091
# Extracting package 47601 / 74091
# Extracting package 47701 / 74091
# Extracting package 47801 / 74091
# Extracting package 47901 / 74091
# Extracting package 48001 / 74091
# Extracting package 48101 / 74091
# Extracting package 48201 / 74091
# Extracting package 48301 / 74091
# Extracting package 48401 / 74091
# Extracting package 48501 / 74091
# Extracting package 48601 / 74091
# Extracting package 48701 / 74091
# Extracting package 48801 / 74091
# Extracting package 48901 / 74091
# Extracting package 49001 / 74091
# Extracting package 49101 / 74091
# Extracting package 49201 / 74091
# Extracting package 49301 / 74091
# Extracting package 49401 / 74091
# Extracting package 49501 / 74091
# Extracting package 49601 / 74091
# Extracting package 49701 / 74091
# Extracting package 49801 / 74091
# Extracting package 49901 / 74091
# Extracting package 50001 / 74091
# Extracting package 50101 / 74091
# Extracting package 50201 / 74091
# Extracting package 50301 / 74091
# Extracting package 50401 / 74091
# Extracting package 50501 / 74091
# Extracting package 50601 / 74091
# Extracting package 50701 / 74091
# Extracting package 50801 / 74091
# Extracting package 50901 / 74091
# Extracting package 51001 / 74091
# Extracting package 51101 / 74091
# Extracting package 51201 / 74091
# Extracting package 51301 / 74091
# Extracting package 51401 / 74091
# Extracting package 51501 / 74091
# Extracting package 51601 / 74091
# Extracting package 51701 / 74091
# Extracting package 51801 / 74091
# Extracting package 51901 / 74091
# Extracting package 52001 / 74091
# Extracting package 52101 / 74091
# Extracting package 52201 / 74091
# Extracting package 52301 / 74091
# Extracting package 52401 / 74091
# Extracting package 52501 / 74091
# Extracting package 52601 / 74091
# Extracting package 52701 / 74091
# Extracting package 52801 / 74091
# Extracting package 52901 / 74091
# Extracting package 53001 / 74091
# Extracting package 53101 / 74091
# Extracting package 53201 / 74091
# Extracting package 53301 / 74091
# Extracting package 53401 / 74091
# Extracting package 53501 / 74091
# Extracting package 53601 / 74091
# Extracting package 53701 / 74091
# Extracting package 53801 / 74091
# Extracting package 53901 / 74091
# Extracting package 54001 / 74091
# Extracting package 54101 / 74091
# Extracting package 54201 / 74091
# Extracting package 54301 / 74091
# Extracting package 54401 / 74091
# Extracting package 54501 / 74091
# Extracting package 54601 / 74091
# Extracting package 54701 / 74091
# Extracting package 54801 / 74091
# Extracting package 54901 / 74091
# Extracting package 55001 / 74091
# Extracting package 55101 / 74091
# Extracting package 55201 / 74091
# Extracting package 55301 / 74091
# Extracting package 55401 / 74091
# Extracting package 55501 / 74091
# Extracting package 55601 / 74091
# Extracting package 55701 / 74091
# Extracting package 55801 / 74091
# Extracting package 55901 / 74091
# Extracting package 56001 / 74091
# Extracting package 56101 / 74091
# Extracting package 56201 / 74091
# Extracting package 56301 / 74091
# Extracting package 56401 / 74091
# Extracting package 56501 / 74091
# Extracting package 56601 / 74091
# Extracting package 56701 / 74091
# Extracting package 56801 / 74091
# Extracting package 56901 / 74091
# Extracting package 57001 / 74091
# Extracting package 57101 / 74091
# Extracting package 57201 / 74091
# Extracting package 57301 / 74091
# Extracting package 57401 / 74091
# Extracting package 57501 / 74091
# Extracting package 57601 / 74091
# Extracting package 57701 / 74091
# Extracting package 57801 / 74091
# Extracting package 57901 / 74091
# Extracting package 58001 / 74091
# Extracting package 58101 / 74091
# Extracting package 58201 / 74091
# Extracting package 58301 / 74091
# Extracting package 58401 / 74091
# Extracting package 58501 / 74091
# Extracting package 58601 / 74091
# Extracting package 58701 / 74091
# Extracting package 58801 / 74091
# Extracting package 58901 / 74091
# Extracting package 59001 / 74091
# Extracting package 59101 / 74091
# Extracting package 59201 / 74091
# Extracting package 59301 / 74091
# Extracting package 59401 / 74091
# Extracting package 59501 / 74091
# Extracting package 59601 / 74091
# Extracting package 59701 / 74091
# Extracting package 59801 / 74091
# Extracting package 59901 / 74091
# Extracting package 60001 / 74091
# Extracting package 60101 / 74091
# Extracting package 60201 / 74091
# Extracting package 60301 / 74091
# Extracting package 60401 / 74091
# Extracting package 60501 / 74091
# Extracting package 60601 / 74091
# Extracting package 60701 / 74091
# Extracting package 60801 / 74091
# Extracting package 60901 / 74091
# Extracting package 61001 / 74091
# Extracting package 61101 / 74091
# Extracting package 61201 / 74091
# Extracting package 61301 / 74091
# Extracting package 61401 / 74091
# Extracting package 61501 / 74091
# Extracting package 61601 / 74091
# Extracting package 61701 / 74091
# Extracting package 61801 / 74091
# Extracting package 61901 / 74091
# Extracting package 62001 / 74091
# Extracting package 62101 / 74091
# Extracting package 62201 / 74091
# Extracting package 62301 / 74091
# Extracting package 62401 / 74091
# Extracting package 62501 / 74091
# Extracting package 62601 / 74091
# Extracting package 62701 / 74091
# Extracting package 62801 / 74091
# Extracting package 62901 / 74091
# Extracting package 63001 / 74091
# Extracting package 63101 / 74091
# Extracting package 63201 / 74091
# Extracting package 63301 / 74091
# Extracting package 63401 / 74091
# Extracting package 63501 / 74091
# Extracting package 63601 / 74091
# Extracting package 63701 / 74091
# Extracting package 63801 / 74091
# Extracting package 63901 / 74091
# Extracting package 64001 / 74091
# Extracting package 64101 / 74091
# Extracting package 64201 / 74091
# Extracting package 64301 / 74091
# Extracting package 64401 / 74091
# Extracting package 64501 / 74091
# Extracting package 64601 / 74091
# Extracting package 64701 / 74091
# Extracting package 64801 / 74091
# Extracting package 64901 / 74091
# Extracting package 65001 / 74091
# Extracting package 65101 / 74091
# Extracting package 65201 / 74091
# Extracting package 65301 / 74091
# Extracting package 65401 / 74091
# Extracting package 65501 / 74091
# Extracting package 65601 / 74091
# Extracting package 65701 / 74091
# Extracting package 65801 / 74091
# Extracting package 65901 / 74091
# Extracting package 66001 / 74091
# Extracting package 66101 / 74091
# Extracting package 66201 / 74091
# Extracting package 66301 / 74091
# Extracting package 66401 / 74091
# Extracting package 66501 / 74091
# Extracting package 66601 / 74091
# Extracting package 66701 / 74091
# Extracting package 66801 / 74091
# Extracting package 66901 / 74091
# Extracting package 67001 / 74091
# Extracting package 67101 / 74091
# Extracting package 67201 / 74091
# Extracting package 67301 / 74091
# Extracting package 67401 / 74091
# Extracting package 67501 / 74091
# Extracting package 67601 / 74091
# Extracting package 67701 / 74091
# Extracting package 67801 / 74091
# Extracting package 67901 / 74091
# Extracting package 68001 / 74091
# Extracting package 68101 / 74091
# Extracting package 68201 / 74091
# Extracting package 68301 / 74091
# Extracting package 68401 / 74091
# Extracting package 68501 / 74091
# Extracting package 68601 / 74091
# Extracting package 68701 / 74091
# Extracting package 68801 / 74091
# Extracting package 68901 / 74091
# Extracting package 69001 / 74091
# Extracting package 69101 / 74091
# Extracting package 69201 / 74091
# Extracting package 69301 / 74091
# Extracting package 69401 / 74091
# Extracting package 69501 / 74091
# Extracting package 69601 / 74091
# Extracting package 69701 / 74091
# Extracting package 69801 / 74091
# Extracting package 69901 / 74091
# Extracting package 70001 / 74091
# Extracting package 70101 / 74091
# Extracting package 70201 / 74091
# Extracting package 70301 / 74091
# Extracting package 70401 / 74091
# Extracting package 70501 / 74091
# Extracting package 70601 / 74091
# Extracting package 70701 / 74091
# Extracting package 70801 / 74091
# Extracting package 70901 / 74091
# Extracting package 71001 / 74091
# Extracting package 71101 / 74091
# Extracting package 71201 / 74091
# Extracting package 71301 / 74091
# Extracting package 71401 / 74091
# Extracting package 71501 / 74091
# Extracting package 71601 / 74091
# Extracting package 71701 / 74091
# Extracting package 71801 / 74091
# Extracting package 71901 / 74091
# Extracting package 72001 / 74091
# Extracting package 72101 / 74091
# Extracting package 72201 / 74091
# Extracting package 72301 / 74091
# Extracting package 72401 / 74091
# Extracting package 72501 / 74091
# Extracting package 72601 / 74091
# Extracting package 72701 / 74091
# Extracting package 72801 / 74091
# Extracting package 72901 / 74091
# Extracting package 73001 / 74091
# Extracting package 73101 / 74091
# Extracting package 73201 / 74091
# Extracting package 73301 / 74091
# Extracting package 73401 / 74091
# Extracting package 73501 / 74091
# Extracting package 73601 / 74091
# Extracting package 73701 / 74091
# Extracting package 73801 / 74091
# Extracting package 73901 / 74091
# Extracting package 74001 / 74091

# %% [markdown]
# We now have the setup.py and requirements files for every pypi package. I use my own fork of [this repository](https://github.com/landscapeio/requirements-detector) to find the requirements for every package with the following script:
#
# ```bash
# for p in packages/*
# do
#   echo $p
#   detect-requirements $p
#   echo ''
# done
# ```
#
# I will parse the output of this using a different notebook.
